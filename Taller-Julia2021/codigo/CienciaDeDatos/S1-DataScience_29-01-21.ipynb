# %% [markdown]
# # Ciencia de Datos con Julia
# - Óscar Alvarado
# - Oscar Esquivel

# %% [markdown]
# ___

# %% [markdown]
# ## Leyendo datos

# %% [markdown]
# Los podemos descargar de aquí: http://bit.ly/29mtzIY

# %%
#using Pkg; Pkg.add("CSV")
using CSV

# %% [markdown]
# - Cargando un CSV

# %%
datos = CSV.File("../../datos/Magic/magic04.csv")
# Out:
# 19019-element CSV.File{false}:
#  CSV.Row: (28.7967 = 31.6036, 16.0021 = 11.7235, 2.6449 = 2.5185, 0.3918 = 0.5303, 0.1982 = 0.3773, 27.7004 = 26.2722, 22.011 = 23.8238, -8.2027 = -9.9574, 40.092 = 6.3609, 81.8828 = 205.261, g = "g")
#  CSV.Row: (28.7967 = 162.052, 16.0021 = 136.031, 2.6449 = 4.0612, 0.3918 = 0.0374, 0.1982 = 0.0187, 27.7004 = 116.741, 22.011 = -64.858, -8.2027 = -45.216, 40.092 = 76.96, 81.8828 = 256.788, g = "g")
#  CSV.Row: (28.7967 = 23.8172, 16.0021 = 9.5728, 2.6449 = 2.3385, 0.3918 = 0.6147, 0.1982 = 0.3922, 27.7004 = 27.2107, 22.011 = -6.4633, -8.2027 = -7.1513, 40.092 = 10.449, 81.8828 = 116.737, g = "g")
#  CSV.Row: (28.7967 = 75.1362, 16.0021 = 30.9205, 2.6449 = 3.1611, 0.3918 = 0.3168, 0.1982 = 0.1832, 27.7004 = -5.5277, 22.011 = 28.5525, -8.2027 = 21.8393, 40.092 = 4.648, 81.8828 = 356.462, g = "g")
# ...

# %%
typeof(datos)
# Out:
# CSV.File{false}

# %%
for row ∈ datos
    println(row)
end
# Out:
# AbstractDataFrame is not iterable. Use eachrow(df) to get a row iterator or eachcol(df) to get a column iterator
#
# Stacktrace:
#  [1] error(::String) at ./error.jl:33
#  [2] iterate(::DataFrame) at /home/oscar/.julia/packages/DataFrames/GtZ1l/src/abstractdataframe/iteration.jl:23
#  [3] top-level scope at ./In[42]:1
#  [4] include_string(::Function, ::Module, ::String, ::String) at ./loading.jl:1091

# %%
#using Pkg; Pkg.add("DataFrames")
using DataFrames
#VegaLite.jl
# Out:
#   Resolving package versions...
# No Changes to `~/.julia/environments/v1.5/Project.toml`
# No Changes to `~/.julia/environments/v1.5/Manifest.toml`

# %% [markdown]
# - Usando DataFrames, primera forma

# %%
datos = DataFrame(CSV.File("../../datos/Magic/magic04.csv"))
# Out:
# 19019×11 DataFrame. Omitted printing of 5 columns
# │ Row   │ 28.7967 │ 16.0021 │ 2.6449  │ 0.3918  │ 0.1982  │ 27.7004  │
# │       │ Float64 │ Float64 │ Float64 │ Float64 │ Float64 │ Float64  │
# ├───────┼─────────┼─────────┼─────────┼─────────┼─────────┼──────────┤
# │ 1     │ 31.6036 │ 11.7235 │ 2.5185  │ 0.5303  │ 0.3773  │ 26.2722  │
# │ 2     │ 162.052 │ 136.031 │ 4.0612  │ 0.0374  │ 0.0187  │ 116.741  │
# │ 3     │ 23.8172 │ 9.5728  │ 2.3385  │ 0.6147  │ 0.3922  │ 27.2107  │
# │ 4     │ 75.1362 │ 30.9205 │ 3.1611  │ 0.3168  │ 0.1832  │ -5.5277  │
# │ 5     │ 51.624  │ 21.1502 │ 2.9085  │ 0.242   │ 0.134   │ 50.8761  │
# │ 6     │ 48.2468 │ 17.3565 │ 3.0332  │ 0.2529  │ 0.1515  │ 8.573    │
# │ 7     │ 26.7897 │ 13.7595 │ 2.5521  │ 0.4236  │ 0.2174  │ 29.6339  │
# │ 8     │ 96.2327 │ 46.5165 │ 4.154   │ 0.0779  │ 0.039   │ 110.355  │
# │ 9     │ 46.7619 │ 15.1993 │ 2.5786  │ 0.3377  │ 0.1913  │ 24.7548  │
# ...

# %%
datos = CSV.File("../../datos/Magic/magic04.csv") |> DataFrame
# Out:
# 19019×11 DataFrame. Omitted printing of 5 columns
# │ Row   │ 28.7967 │ 16.0021 │ 2.6449  │ 0.3918  │ 0.1982  │ 27.7004  │
# │       │ Float64 │ Float64 │ Float64 │ Float64 │ Float64 │ Float64  │
# ├───────┼─────────┼─────────┼─────────┼─────────┼─────────┼──────────┤
# │ 1     │ 31.6036 │ 11.7235 │ 2.5185  │ 0.5303  │ 0.3773  │ 26.2722  │
# │ 2     │ 162.052 │ 136.031 │ 4.0612  │ 0.0374  │ 0.0187  │ 116.741  │
# │ 3     │ 23.8172 │ 9.5728  │ 2.3385  │ 0.6147  │ 0.3922  │ 27.2107  │
# │ 4     │ 75.1362 │ 30.9205 │ 3.1611  │ 0.3168  │ 0.1832  │ -5.5277  │
# │ 5     │ 51.624  │ 21.1502 │ 2.9085  │ 0.242   │ 0.134   │ 50.8761  │
# │ 6     │ 48.2468 │ 17.3565 │ 3.0332  │ 0.2529  │ 0.1515  │ 8.573    │
# │ 7     │ 26.7897 │ 13.7595 │ 2.5521  │ 0.4236  │ 0.2174  │ 29.6339  │
# │ 8     │ 96.2327 │ 46.5165 │ 4.154   │ 0.0779  │ 0.039   │ 110.355  │
# │ 9     │ 46.7619 │ 15.1993 │ 2.5786  │ 0.3377  │ 0.1913  │ 24.7548  │
# ...

# %%
df = CSV.read("../../datos/Magic/magic04.csv", DataFrame)
# Out:
# 19019×11 DataFrame. Omitted printing of 5 columns
# │ Row   │ 28.7967 │ 16.0021 │ 2.6449  │ 0.3918  │ 0.1982  │ 27.7004  │
# │       │ Float64 │ Float64 │ Float64 │ Float64 │ Float64 │ Float64  │
# ├───────┼─────────┼─────────┼─────────┼─────────┼─────────┼──────────┤
# │ 1     │ 31.6036 │ 11.7235 │ 2.5185  │ 0.5303  │ 0.3773  │ 26.2722  │
# │ 2     │ 162.052 │ 136.031 │ 4.0612  │ 0.0374  │ 0.0187  │ 116.741  │
# │ 3     │ 23.8172 │ 9.5728  │ 2.3385  │ 0.6147  │ 0.3922  │ 27.2107  │
# │ 4     │ 75.1362 │ 30.9205 │ 3.1611  │ 0.3168  │ 0.1832  │ -5.5277  │
# │ 5     │ 51.624  │ 21.1502 │ 2.9085  │ 0.242   │ 0.134   │ 50.8761  │
# │ 6     │ 48.2468 │ 17.3565 │ 3.0332  │ 0.2529  │ 0.1515  │ 8.573    │
# │ 7     │ 26.7897 │ 13.7595 │ 2.5521  │ 0.4236  │ 0.2174  │ 29.6339  │
# │ 8     │ 96.2327 │ 46.5165 │ 4.154   │ 0.0779  │ 0.039   │ 110.355  │
# │ 9     │ 46.7619 │ 15.1993 │ 2.5786  │ 0.3377  │ 0.1913  │ 24.7548  │
# ...

# %%
ENV["COLUMNS"] = 100
# Out:
# "80"

# %%
df = CSV.read("../../datos/Magic/magic04.csv", DataFrame; header = 0)
# Out:
# 19020×11 DataFrame

# %%
nombres = [:Nombre1, :Nombre2, :Nombre3, :Nombre4, :Nombre5, :Nombre6, :Nombre7, :Nombre8, :Nombre9, :Nombre10, :cat]
df = CSV.read("../../datos/Magic/magic04.csv", DataFrame; header = nombres)
# Out:
# 19020×11 DataFrame. Omitted printing of 5 columns
# │ Row   │ Nombre1 │ Nombre2 │ Nombre3 │ Nombre4 │ Nombre5 │ Nombre6  │
# │       │ Float64 │ Float64 │ Float64 │ Float64 │ Float64 │ Float64  │
# ├───────┼─────────┼─────────┼─────────┼─────────┼─────────┼──────────┤
# │ 1     │ 28.7967 │ 16.0021 │ 2.6449  │ 0.3918  │ 0.1982  │ 27.7004  │
# │ 2     │ 31.6036 │ 11.7235 │ 2.5185  │ 0.5303  │ 0.3773  │ 26.2722  │
# │ 3     │ 162.052 │ 136.031 │ 4.0612  │ 0.0374  │ 0.0187  │ 116.741  │
# │ 4     │ 23.8172 │ 9.5728  │ 2.3385  │ 0.6147  │ 0.3922  │ 27.2107  │
# │ 5     │ 75.1362 │ 30.9205 │ 3.1611  │ 0.3168  │ 0.1832  │ -5.5277  │
# │ 6     │ 51.624  │ 21.1502 │ 2.9085  │ 0.242   │ 0.134   │ 50.8761  │
# │ 7     │ 48.2468 │ 17.3565 │ 3.0332  │ 0.2529  │ 0.1515  │ 8.573    │
# │ 8     │ 26.7897 │ 13.7595 │ 2.5521  │ 0.4236  │ 0.2174  │ 29.6339  │
# │ 9     │ 96.2327 │ 46.5165 │ 4.154   │ 0.0779  │ 0.039   │ 110.355  │
# ...

# %%
df = CSV.read("../../datos/Magic/magic04.csv", DataFrame; drop = [1,2,11], header = false)
# Out:
# 19020×8 DataFrame. Omitted printing of 2 columns
# │ Row   │ Column3 │ Column4 │ Column5 │ Column6  │ Column7  │ Column8  │
# │       │ Float64 │ Float64 │ Float64 │ Float64  │ Float64  │ Float64  │
# ├───────┼─────────┼─────────┼─────────┼──────────┼──────────┼──────────┤
# │ 1     │ 2.6449  │ 0.3918  │ 0.1982  │ 27.7004  │ 22.011   │ -8.2027  │
# │ 2     │ 2.5185  │ 0.5303  │ 0.3773  │ 26.2722  │ 23.8238  │ -9.9574  │
# │ 3     │ 4.0612  │ 0.0374  │ 0.0187  │ 116.741  │ -64.858  │ -45.216  │
# │ 4     │ 2.3385  │ 0.6147  │ 0.3922  │ 27.2107  │ -6.4633  │ -7.1513  │
# │ 5     │ 3.1611  │ 0.3168  │ 0.1832  │ -5.5277  │ 28.5525  │ 21.8393  │
# │ 6     │ 2.9085  │ 0.242   │ 0.134   │ 50.8761  │ 43.1887  │ 9.8145   │
# │ 7     │ 3.0332  │ 0.2529  │ 0.1515  │ 8.573    │ 38.0957  │ 10.5868  │
# │ 8     │ 2.5521  │ 0.4236  │ 0.2174  │ 29.6339  │ 20.456   │ -2.9292  │
# │ 9     │ 4.154   │ 0.0779  │ 0.039   │ 110.355  │ 85.0486  │ 43.1844  │
# ...

# %% [markdown]
# ### Parámetros para CSV.File:
# - delim - the delimiter (separator), which can be char or string.
# - header - which row is header or used to rename the headers
# - select - include only these columns (identify by int, string or symbol)
# - drop - inverse of select, which column to drop
# - skipto or datarow - at which which row the data start
# - footerskip - rows to skip at the end of the file
# - limit - how many rows to read (only reliable if threaded=false)
# - type - single type to use to parse whole file
# - types - specify type for each column

# %%
df[1:2,:]
# Out:
# 2×8 DataFrame. Omitted printing of 1 columns
# │ Row │ Column3 │ Column4 │ Column5 │ Column6 │ Column7 │ Column8 │ Column9 │
# │     │ Float64 │ Float64 │ Float64 │ Float64 │ Float64 │ Float64 │ Float64 │
# ├─────┼─────────┼─────────┼─────────┼─────────┼─────────┼─────────┼─────────┤
# │ 1   │ 2.6449  │ 0.3918  │ 0.1982  │ 27.7004 │ 22.011  │ -8.2027 │ 40.092  │
# │ 2   │ 2.5185  │ 0.5303  │ 0.3773  │ 26.2722 │ 23.8238 │ -9.9574 │ 6.3609  │

# %% [markdown]
# ## Siguiendo con [DataFrames.jl](https://dataframes.juliadata.org/stable/man/getting_started/)

# %%
df = DataFrame(Nombre = 1:4, B = ["M", "F", "F", "M"])
# Out:
# 4×2 DataFrame
# │ Row │ Nombre │ B      │
# │     │ Int64  │ String │
# ├─────┼────────┼────────┤
# │ 1   │ 1      │ M      │
# │ 2   │ 2      │ F      │
# │ 3   │ 3      │ F      │
# │ 4   │ 4      │ M      │

# %% [markdown]
# **Columns can be directly (i.e. without copying) accessed via df.col, df."col", df[!, :col] or df[!, "col"]**
#
# df[!, :col] -> No hace una copia!
#
# df[:, :col] -> Hace una copia!

# %%
df[!, :Nombre]
# Out:
# 4-element Array{Int64,1}:
#  1
#  2
#  3
#  4

# %%
df[:, :Nombre]
# Out:
# 4-element Array{Int64,1}:
#  1
#  2
#  3
#  4

# %%
names(df)
# Out:
# 2-element Array{String,1}:
#  "Nombre"
#  "B"

# %%
df.C
# Out:
# ArgumentError: column name :C not found in the data frame; existing most similar names are: :B
#
# Stacktrace:
#  [1] lookupname at /home/oscar/.julia/packages/DataFrames/GtZ1l/src/other/index.jl:289 [inlined]
#  [2] getindex at /home/oscar/.julia/packages/DataFrames/GtZ1l/src/other/index.jl:295 [inlined]
#  [3] getindex(::DataFrame, ::typeof(!), ::Symbol) at /home/oscar/.julia/packages/DataFrames/GtZ1l/src/dataframe/dataframe.jl:435
#  [4] getproperty(::DataFrame, ::Symbol) at /home/oscar/.julia/packages/DataFrames/GtZ1l/src/abstractdataframe/abstractdataframe.jl:346
#  [5] top-level scope at In[65]:1
#  [6] include_string(::Function, ::Module, ::String, ::String) at ./loading.jl:1091

# %%
df.C = 5:8
df
# Out:
# 4×3 DataFrame
# │ Row │ Nombre │ B      │ C     │
# │     │ Int64  │ String │ Int64 │
# ├─────┼────────┼────────┼───────┤
# │ 1   │ 1      │ M      │ 5     │
# │ 2   │ 2      │ F      │ 6     │
# │ 3   │ 3      │ F      │ 7     │
# │ 4   │ 4      │ M      │ 8     │

# %%
size(df)
# Out:
# (4, 3)

# %%
first(df,3)
# Out:
# 3×3 DataFrame
# │ Row │ Nombre │ B      │ C     │
# │     │ Int64  │ String │ Int64 │
# ├─────┼────────┼────────┼───────┤
# │ 1   │ 1      │ M      │ 5     │
# │ 2   │ 2      │ F      │ 6     │
# │ 3   │ 3      │ F      │ 7     │

# %%
last(df, 3)
# Out:
# 3×3 DataFrame
# │ Row │ Nombre │ B      │ C     │
# │     │ Int64  │ String │ Int64 │
# ├─────┼────────┼────────┼───────┤
# │ 1   │ 2      │ F      │ 6     │
# │ 2   │ 3      │ F      │ 7     │
# │ 3   │ 4      │ M      │ 8     │

# %%
df[1:2,1:end]
# Out:
# 2×3 DataFrame
# │ Row │ Nombre │ B      │ C     │
# │     │ Int64  │ String │ Int64 │
# ├─────┼────────┼────────┼───────┤
# │ 1   │ 1      │ M      │ 5     │
# │ 2   │ 2      │ F      │ 6     │

# %%
select(df, Not(:B))
# Out:
# 4×2 DataFrame
# │ Row │ Nombre │ C     │
# │     │ Int64  │ Int64 │
# ├─────┼────────┼───────┤
# │ 1   │ 1      │ 5     │
# │ 2   │ 2      │ 6     │
# │ 3   │ 3      │ 7     │
# │ 4   │ 4      │ 8     │

# %%
describe(df)
# Out:
# 3×8 DataFrame
# │ Row │ variable │ mean   │ min │ median │ max │ nunique │ nmissing │ eltype   │
# │     │ Symbol   │ Union… │ Any │ Union… │ Any │ Union…  │ Nothing  │ DataType │
# ├─────┼──────────┼────────┼─────┼────────┼─────┼─────────┼──────────┼──────────┤
# │ 1   │ Nombre   │ 2.5    │ 1   │ 2.5    │ 4   │         │          │ Int64    │
# │ 2   │ B        │        │ F   │        │ M   │ 2       │          │ String   │
# │ 3   │ C        │ 6.5    │ 5   │ 6.5    │ 8   │         │          │ Int64    │

# %% [markdown]
# ## Segunda sesión

# %%
ENV["COLUMNS"] = 100
# Out:
# 100

# %%
ENV["LINES"] = 10
# Out:
# 10

# %%
?CSV.File
# Out:
#   CSV.File(source; kwargs...) => CSV.File
#
#   Read a UTF-8 CSV input and return a CSV.File object.
#
#   The source argument can be one of:
#
#     •    filename given as a string or FilePaths.jl type
#
#     •    an AbstractVector{UInt8} like a byte buffer or codeunits(string)
#
#     •    an IOBuffer
#
#   To read a csv file from a url, use the HTTP.jl package, where the
#   HTTP.Response body can be passed like:
#
#   f = CSV.File(HTTP.get(url).body)
#
#   For other IO or Cmd inputs, you can pass them like: f = CSV.File(read(obj)).
#
#   Opens the file and uses passed arguments to detect the number of columns and
#   column types, unless column types are provided manually via the types
#   keyword argument. Note that passing column types manually can slightly
#   increase performance for each column type provided (column types can be
#   given as a Vector for all columns, or specified per column via name or index
#   in a Dict).
#
# ...
